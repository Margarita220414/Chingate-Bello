# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data_csv=pd.read_csv("employees.csv")
data_csv
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %%
data_csv["HIRE_DATE"] = pd.to_datetime(data_csv["HIRE_DATE"])
data_csv["HIRE_DATE"]
# Out:
# C:\Users\CIDE\AppData\Local\Temp\ipykernel_11152\205189379.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data_csv["HIRE_DATE"] = pd.to_datetime(data_csv["HIRE_DATE"])
# 0    2007-06-21
# 1    2008-01-13
# 2    2003-09-17
# 3    2004-02-17
# 4    2005-08-17
# 5    2002-06-07
# 6    2002-06-07
# 7    2002-06-07
# 8    2002-06-07
# 9    2003-06-17
# 10   2005-09-21
# 11   2001-01-13
# 12   2006-01-03
# 13   2007-05-21
# 14   2005-06-25
# 15   2006-02-05
# 16   2007-02-07
# 17   2002-08-17
# 18   2002-08-16
# 19   2005-09-28
# 20   2005-09-30
# 21   2006-03-07
# 22   2007-12-07
# 23   2002-12-07
# 24   2003-05-18
# 25   2005-12-24
# 26   2005-07-24
# 27   2006-11-15
# 28   2007-08-10
# 29   2004-07-18
# 30   2005-04-10
# 31   2003-05-01
# 32   2005-10-10
# 33   2007-11-16
# 34   2005-07-16
# 35   2006-09-28
# 36   2007-01-14
# ...

# %%
data_csv.dtypes
# Out:
# EMPLOYEE_ID                int64
# FIRST_NAME                object
# LAST_NAME                 object
# EMAIL                     object
# PHONE_NUMBER              object
# HIRE_DATE         datetime64[ns]
# JOB_ID                    object
# SALARY                     int64
# COMMISSION_PCT            object
# MANAGER_ID                object
# DEPARTMENT_ID              int64
# dtype: object

# %% [markdown]
# EMPLOYEE_ID        int64 - cuantitativo - discreta
# FIRST_NAME        object - cualitativo - nominal
# LAST_NAME         object - cualitativo - nominal
# EMAIL             object - cualitativo - nominal
# PHONE_NUMBER      object - cuantitativa - nominal
# HIRE_DATE         object - cualitativo - discreta
# JOB_ID            object - cualitativo - ordinales
# SALARY             int64 - cuantitativo - discreta
# MANAGER_ID        object  - cualitativo - discreta
# DEPARTMENT_ID      int64 - cuantitativo - discreta
# dtype: object
# Depende del contexto: Si es un código, es nominal. Si tiene rangos, es ordinal.son nombres

# %%
x = ["SALARY"]
y =["DEPARTMENT_ID"]
plt.plot(x, y) # crear grafico de lineas
# Agregar título y etiquetas
plt.title('Gráfico de Líneas Básico')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
# Mostrar el gráfico
plt.show()

# %%
categorias = ["FIRST_NAME"]
valores = ["SALARY"] 
# Crear gráfico de barras
plt.bar(categorias, valores, color='skyblue') 
# Agregar título y etiquetas
plt.title('Gráfico de Barras')
plt.xlabel('Categorías')
plt.ylabel('Valores') 
# Mostrar el gráfico
plt.show()
