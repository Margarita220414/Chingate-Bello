# %%
import pandas as pd
data_csv=pd.read_csv("employees.csv")
data_csv
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %%
data_excel=pd.read_excel("aaa.xlsx")
data_excel
# Out:
#                                 Crop  2012-13  2013-14  2014-15  2015-16  \
# 0                                NaN      NaN      NaN      NaN      NaN
# 1                               Rice  1052.32  1066.46  1054.82  1044.08
# 2                              Wheat   935.10   958.50   865.27   922.88
# 3                              Jowar    52.80    55.42    54.45    42.38
# 4                              Bajra    87.40    92.50    91.84    80.67
# 5                              Maize   222.58   242.60   241.73   225.67
# 6                               Ragi    15.70    19.83    20.61    18.22
# 7                      Small Millets     4.40     4.30     3.86     3.91
# 8                             Barley    17.50    18.31    16.13    14.38
# 9                      Nutri Cereals   160.30   172.05   170.76   145.17
# 10              Nutri/Coarse Cereals   400.38   432.95   428.62   385.22
# 11                           Cereals  2387.80  2457.91  2348.71  2352.18
# ...

# %%
data_json=pd.read_json("datos_json.json")
data_json
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...
